# %%
import numpy as np

import pandas as pd

import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col = 0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df1["A"].hist() # Here we used a pandas inbuilt feature - by Matplotlib
# Out:
# <AxesSubplot:>

# %%
# Or we can use this method:


df1['A'].plot(kind = 'hist', bins=  20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area(alpha = 0.4)
# Out:
# <AxesSubplot:>

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar() # Takes index as a category
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked =True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(x = df1.index, y = 'A')

# NOt working - Figure out why
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# e:\Training\Udemy\Python DataScience\PythonDataScience\Python DS\pandas_builtin_data_visualization.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/e%3A/Training/Udemy/Python%20DataScience/PythonDataScience/Python%20DS/pandas_builtin_data_visualization.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> df1.plot.line(x = df1.index, y = 'A')
#
# File c:\Users\My PC\anaconda3\lib\site-packages\pandas\plotting\_core.py:1041, in PlotAccessor.line(self, x, y, **kwargs)
#     976 @Appender(
#     977     """
#     978     See Also
#    (...)
#    1033 @Appender(_bar_or_line_doc)
#    1034 def line(self, x=None, y=None, **kwargs):
#    1035     """
#    1036     Plot Series or DataFrame as lines.
#    1037
#    1038     This function is useful to plot lines using DataFrame's values
#    1039     as coordinates.
# ...

# %%
df1.plot.scatter(x = 'A', y= 'B', c  = 'C') # Here we set color as C, so, basically a 3D plot - with color being the third dimension
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x = 'A', y= 'B', s  = 'C') # Size being too small
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x = 'A', y= 'B', s  = df1['C']*50) # Now, size is the 3rd dimension
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns = ['A', 'B'])

# %%
df.plot.hexbin(x = 'A', y = 'B', gridsize = 30)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
